# %%
# Oppgave 1

dagensOrd= input("skriv dagens skjellsord: ")

while dagensOrd != "":

    print("god dayum, ro ned reka!")
    print("bra det er snart helg")

    dag = input("Noe mer du har på hjertet? (ja/nei): ")

    if dag == "nei":
        print("god helg!")
        break

    dagensOrd = input("skriv dagens skjellsord: ")
# Out:
# god dayum, ro ned reka!
# bra det er snart helg
# god dayum, ro ned reka!
# bra det er snart helg
# god helg!

# %%
tall = int(input("skriv inn et tall mellom 0-100: "))

while tall<0 or tall>100:
    print("nono,no. prøv igjen: ")
    tall = int(input("skriv inn et tall mellom 0-100: "))

print(f"tallet ditt er {tall}")
# Out:
# kan du ikke telle? prøv igjen:
# tallet ditt er 12

# %%
# oppgave til for-


for x in range(0,5):
    print("jeg liker programmering")
# Out:
# jeg liker programmering
# jeg liker programmering
# jeg liker programmering
# jeg liker programmering
# jeg liker programmering

# %%
for number in range(10,5,-1):
    print(number)
# Out:
# 10
# 9
# 8
# 7
# 6

# %%
rantall = [16,23,43,11,12,14,2]

total =sum(rantall)
print(total)
# Out:
# 121

# %%
numbers = [74,19,105,20, -2, 67, 77, 124, -45, 38]

nyliste = []

for n in numbers: # husk å referere til numberene, ikke tall mellom 0 til 100.
    if n >= 0 or n <= 100 :
            nyliste.append(n)

print(nyliste)

gjennomsnitt = sum(numbers)/len(numbers)
total = sum(numbers)
print ("total er: ",total)
print ("totalen er: ", gjennomsnitt)
# Out:
# [74, 19, 105, 20, -2, 67, 77, 124, -45, 38]
# total er:  477
# totalen er:  47.7
